# %% [markdown]
# ## LESSON 3
#
# - Jupyter Hub
# - ..stat in pandas
# - spacy example

# %%
import pandas as pd

# %%
import numpy as np

# %%
yann_df = pd.read_csv('lipa_sipto.csv')

# %%
yann_df
# Out:
#      Unnamed: 0                       AP                        PN  \
# 0             0  CN201910205498 20120629    CN109905904 A 20190618
# 1             1   EP20190174532 20120120     EP3544326 A1 20190925
# 2             2  US201816227196 20181220  US2019124717 A1 20190425
# 3             3  US201615764513 20160930  US2019059030 A1 20190221
# 4             4  US201816116260 20180829  US2018376529 A1 20181227
# ..          ...                      ...                       ...
# 200           0   WO2011US20838 20110111  WO2011085370 A2 20110714
# 201           1   WO2011US20637 20110110  WO2011085290 A1 20110714
# 202           2   WO2010US58940 20101203  WO2011069092 A1 20110609
# 203           3   EP20100751896 20100824     EP2609779 A1 20130703
# 204           4   WO2010EP62347 20100824  WO2012025149 A1 20120301
#
#              PD                                                 PR  \
# 0    2019-06-18   CN201910205498 20120629; CN201210226993 20120629
# 1    2019-09-25  US201161435047P 20110121; EP20120737140 201201...
# 2    2019-04-25  US201816227196 20181220; US201715601097 201705...
# 3    2019-02-21    CN201510640863 20150930; WO2016KR10986 20160930
# 4    2018-12-27  US201816116260 20180829; US201715326028 201701...
# ..          ...                                                ...
# 200  2011-07-14                             US20100685651 20100111
# 201  2011-07-14   US20100293423P 20100108; US20100304199P 20100212
# 202  2011-06-09  US20100322245P 20100408; US20090266726P 200912...
# 203  2013-07-03                             WO2010EP62347 20100824
# 204  2012-03-01                             WO2010EP62347 20100824
#
#                                                    CCI  \
# 0                                           H04W36/125
# 1                                            H04W76/11
# 2                                            H04W76/32
# 3    H04L5/001; H04L5/0098; H04W36/0069; H04W36/08;...
# 4                                 H04W76/12; H04W76/15
# ..                                                 ...
# 200                                          H04W48/08
# 201                                          H04W48/17
# 202                   H04L63/30; H04W8/082; H04W12/001
# 203                                          H04W68/00
# 204                                          H04W68/00
#
#                                                    CCA  \
# 0                                            H04W8/082
# 1                      H04W8/082; H04W76/18; H04W76/30
# 2                                           H04W84/045
# 3                                 H04W8/082; H04W76/34
# 4                                 H04W88/08; H04W92/20
# ..                                                 ...
# 200        H04W76/10; H04W76/12; H04W80/04; H04W84/045
# 201  H04W4/06; H04W48/08; H04W48/16; H04W68/00; H04...
# 202        H04W76/12; H04W84/045; H04W88/06; H04W92/22
# 203                              H04W84/045; H04W92/02
# 204                              H04W84/045; H04W92/02
#
#                                                     TI     PD_dt64
# 0                                Access control method  2019-06-18
# 1    NETWORK APPARATUS AND PROCESS TO DETERMINE THE...  2019-09-25
# 2             RESPONSE TO A NON ACCESS STRATUM MESSAGE  2019-04-25
# 3    METHODS AND DEVICES FOR SUPPORTING RELEASE OF ...  2019-02-21
# 4    (A1)\r\nMETHOD AND APPARATUS FOR SUPPORTING LO...  2018-12-27
# ..                                                 ...         ...
# 200  (A2 A3 A4)\r\nSYSTEM AND METHOD FOR ENABLING D...  2011-07-14
# 201  METHOD AND APPARATUS FOR BROADCASTING SUPPORT ...  2011-07-14
# 202  EXTENDED LOCAL IP ACCESS FOR A CONVERGED GATEW...  2011-06-09
# 203  (A1 B1)\r\nNETWORK DEVICES AND METHOD FOR SUPP...  2013-07-03
# 204  NETWORK DEVICES AND METHOD FOR SUPPORTING DOWN...  2012-03-01
#
# [205 rows x 9 columns]

# %%
# symple statisticalanalysis of CCI classes
myCCI_classes = yann_df.CCI.fillna('').tolist()

# %%
myCCI_classes = [classes for classes in myCCI_classes if classes !='']

# %%
myCCI_classes_str = ';'.join(myCCI_classes)
# divide again to separate classes
myCCI_classes_list=myCCI_classes_str.split(';')

# %%
# create a one-column pandas in order to use the pandas methods available
all_classes_pandas = pd.DataFrame(myCCI_classes_list, columns=['classes'])

# %%
all_classes_pandas['classes'].value_counts()
# Out:
#  H04W76/22    49
# H04W8/082     47
# H04W36/00     41
#  H04W36/32    41
#  H04W76/20    41
#               ..
# H04W4/06       1
#  H04W76/10     1
#  H04W76/12     1
# H04W28/08      1
# H04W76/10      1
# Name: classes, Length: 72, dtype: int64

# %%
all_classes_pandas['classes'].value_counts(normalize=True)
# Out:
#  H04W76/22    0.089091
# H04W8/082     0.085455
# H04W36/00     0.074545
#  H04W36/32    0.074545
#  H04W76/20    0.074545
#                 ...
# H04W4/06      0.001818
#  H04W76/10    0.001818
#  H04W76/12    0.001818
# H04W28/08     0.001818
# H04W76/10     0.001818
# Name: classes, Length: 72, dtype: float64

# %%
# lets take out the classes that appear only 1 or 2
#this is a seeries
most_popular_classes = all_classes_pandas['classes'].value_counts()
print(len(most_popular_classes))
most_popular_classes_df = pd.DataFrame(most_popular_classes)
most_popular_classes_df
# Out:
# 72
#             classes
#  H04W76/22       49
# H04W8/082        47
# H04W36/00        41
#  H04W36/32       41
#  H04W76/20       41
# ...             ...
# H04W4/06          1
#  H04W76/10        1
#  H04W76/12        1
# H04W28/08         1
# H04W76/10         1
#
# [72 rows x 1 columns]

# %%
(most_popular_classes_df['classes'] >2)
# Out:
#  H04W76/22     True
# H04W8/082      True
# H04W36/00      True
#  H04W36/32     True
#  H04W76/20     True
#               ...
# H04W4/06      False
#  H04W76/10    False
#  H04W76/12    False
# H04W28/08     False
# H04W76/10     False
# Name: classes, Length: 72, dtype: bool

# %%
TOPX = 20
condition=(most_popular_classes_df['classes'] >2)
most_popular_classes_TOPX = most_popular_classes_df.iloc[0:TOPX,]
most_popular_classes_TOPX
# Out:
#                classes
#  H04W76/22          49
# H04W8/082           47
# H04W36/00           41
#  H04W36/32          41
#  H04W76/20          41
#  H04W36/0033        41
#  H04W76/15          13
# H04W76/32           13
# H04W76/12           12
#  H04W36/0083        10
#  H04W48/20          10
# H04W36/0022          9
# H04W48/08            9
#  H04W36/125          8
# H04W48/17            7
# H04W76/11            6
#  H04N21/64738        5
#  H04W48/08           5
# H04N21/2146          5
#  H04W76/34           5

# %%
import matplotlib.pyplot as plt
plot = most_popular_classes_TOPX.plot.pie(y='classes', figsize=(5, 5))

# %%
import spacy

# %%
# To load a model, use spacy.load() with the model name, a shortcut link or a path to the model data directory.
mypath=r'C:\Users\JF30443\pyCODE\DATA_language_models\models\en_vectors_web_lg-2.1.0'

# my language model
nlp = spacy.load(mypath)

# %%
listcls=['A system for controlling video thumbnail images, comprising: an analytics engine comprising at least a plurality of programming instructions stored in a memory operating on a network-connected computing device and adapted to collect at least a plurality of statistics related to at least a user behavior regarding a plurality of electronic media content, the media content comprising at least a video clip; and a distribution engine comprising at least a plurality of programming instructions stored in a memory operating on a network-connected computing device and adapted to receive at least to a plurality of network-connected user devices.','The system of claim 1, wherein the collected statistics comprise at least a user devices hardware capabilities.','The system of claim 1, wherein the collected statistics comprise at least a users browsing behavior.','The system of claim 1, wherein the collected statistics comprise at least a plurality of network statistics.','The system of claim 1, wherein the distribution engine selects media for presentation to a user device based at least in part on at least a portion of statistics collected by an analytics engine.','A method for controlling video thumbnail images, comprising the steps of: receiving, at a distribution engine, a plurality of video media content; processing at least a portion of the media content; producing a plurality of still images based at least in part on at least a portion of the processing results; processing at least a portion of the plurality of static images; presenting at least a portion of the static images to a user; and tracking user behavior based at least in part on at least a portion of the presented static images.','The method of claim 6, further comprising the step of tagging at least a portion of the plurality of still images with a plurality of metadata information tags.','The method of claim 6, further comprising the step of determining at least a uniqueness measure for at least a portion of the plurality of still images.']

# %%
listcls = [claim.strip() for claim in listcls]

# %%
claims_df = pd.DataFrame(columns=['claimtext'])
claims_df['claimtext'] = listcls
claims_df
# Out:
#                                            claimtext
# 0  A system for controlling video thumbnail image...
# 1  The system of claim 1, wherein the collected s...
# 2  The system of claim 1, wherein the collected s...
# 3  The system of claim 1, wherein the collected s...
# 4  The system of claim 1, wherein the distributio...
# 5  A method for controlling video thumbnail image...
# 6  The method of claim 6, further comprising the ...
# 7  The method of claim 6, further comprising the ...

# %%
# get the first noun phrase with a language model

def firstchunck(str):
    mydoc = nlp(str)
    
    # this is the collection of noun phrases in a document:
    return next(mydoc.noun_chunks.text)

# %%
claims_df['whatis'] =claims_df['claimtext'].apply(firstchunck)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-126-07946408d805> in <module>
# ----> 1 claims_df['whatis'] =claims_df['claimtext'].apply(firstchunck)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4040             else:
#    4041                 values = self.astype(object).values
# -> 4042                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4043
#    4044         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-125-2d5e18919dab> in firstchunck(str)
#       5
#       6     # this is the collection of noun phrases in a document:
# ----> 7     for chunck in mydoc.noun_chunks:
#       8         print(chunck)
#       9
#
# doc.pyx in noun_chunks()
#
# ValueError: [E029] noun_chunks requires the dependency parse, which requires a statistical model to be installed and loaded. For more info, see the documentation:
# https://spacy.io/usage/models

# %%
claims_df
# Out:
#                                            claimtext  \
# 0  A system for controlling video thumbnail image...
# 1  The system of claim 1, wherein the collected s...
# 2  The system of claim 1, wherein the collected s...
# 3  The system of claim 1, wherein the collected s...
# 4  The system of claim 1, wherein the distributio...
# 5  A method for controlling video thumbnail image...
# 6  The method of claim 6, further comprising the ...
# 7  The method of claim 6, further comprising the ...
#
#                                               whatis
# 0  <method-wrapper '__next__' of generator object...
# 1  <method-wrapper '__next__' of generator object...
# 2  <method-wrapper '__next__' of generator object...
# 3  <method-wrapper '__next__' of generator object...
# 4  <method-wrapper '__next__' of generator object...
# 5  <method-wrapper '__next__' of generator object...
# 6  <method-wrapper '__next__' of generator object...
# 7  <method-wrapper '__next__' of generator object...

# %%
# lets talk about speed
vector= np.repeat(50, 1000)
vector
# Out:
# array([50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50])

# %%
speed_df = pd.DataFrame(vector,columns=['numeros'])

# %%
speed_df.head()
# Out:
#    numeros
# 0       50
# 1       50
# 2       50
# 3       50
# 4       50

# %%
len(speed_df)
# Out:
# 1000

# %%
import math
import time

# %%
tic=time.time()

for i in range(1000):
    col_name= 'col' + str(i)
    speed_df[col_name]=speed_df['numeros'].apply(math.factorial)
toc = time.time() 
print(f'elapsed time {toc-tic} seconds' )
# Out:
# elapsed time 4.2109479904174805 seconds

# %%
factorial_calculated = speed_df.shape[0]*speed_df.shape[1]
nr= int(speed_df['numeros'][0])
print(f'calculated {factorial_calculated} times {nr} factorial in {toc-tic} seconds')
# Out:
# calculated 1001000 times 50 factorial in 4.2109479904174805 seconds

# %%
# lets try an alphanumeric function
# Out:
# 0    40
# Name: numeros, dtype: int32

# %%
# load description
with open('description.txt','r') as f:
    description_lines=f.readlines()

with open('description.txt','r') as f:
    description_words=f.read()

description_lines = [line for line in description_lines if line !='\n']

# %%
a= len(description_words.split(' '))

# %%
print(f'The description has {a} words')
# Out:
# The description has 5992 words

# %%
desc_df = pd.DataFrame(description_lines,columns=['lines'])

# %%
def look4wordsintext(description_str):
    list_of_words_around=[]
    list_desc = description_str.split(' ')
    list_of_words = ['invention','result', 'solar', 'method','energy','efficiency']
    for i,word in enumerate(list_desc):
        if word in list_of_words:
            start = max(0,i-3)
            end= min(i+3,len(list_desc))
            list_of_words_around.append(' '.join(list_desc[start:end]))
    return list_of_words_around

# %%
desc_df
# Out:
#                                                 lines  \
# 0    Method and arrangement for operating a solar ...
# 1   The invention relates to a method for operatin...
# 2                                  State of the art\n
# 3   Among the so-called regenerative energies, sol...
# 4   To bring energy closer to the values that set ...
# ..                                                ...
# 88                                     ? = P ou Xt)\n
# 89                           Figure imgf000009_0001\n
# 90  P m (t) PJ in cvcle Fig. 2A shows a sketch-lik...
# 91  FIG. 3 shows a sketch of a further solar cell ...
# 92  Finally, FIG. 4 schematically shows a modifica...
#
#                                                  col0  \
# 0                [for operating a solar cell array\n]
# 1   [The invention relates to, relates to a method...
# 2                                                  []
# 3   [so-called regenerative energies, solar energy...
# 4   [To bring energy closer to, economic standard ...
# ..                                                ...
# 88                                                 []
# 89                                                 []
# 90  [view of a solar cell array, to ground lying) ...
# 91  [of a further solar cell arrangement, temperat...
# 92  [power of the solar cell module, and the measu...
#
#                                                  col1  \
# 0                [for operating a solar cell array\n]
# 1   [The invention relates to, relates to a method...
# 2                                                  []
# 3   [so-called regenerative energies, solar energy...
# 4   [To bring energy closer to, economic standard ...
# ..                                                ...
# 88                                                 []
# 89                                                 []
# 90  [view of a solar cell array, to ground lying) ...
# 91  [of a further solar cell arrangement, temperat...
# 92  [power of the solar cell module, and the measu...
#
#                                                  col2  \
# 0                [for operating a solar cell array\n]
# 1   [The invention relates to, relates to a method...
# 2                                                  []
# 3   [so-called regenerative energies, solar energy...
# 4   [To bring energy closer to, economic standard ...
# ..                                                ...
# 88                                                 []
# 89                                                 []
# 90  [view of a solar cell array, to ground lying) ...
# 91  [of a further solar cell arrangement, temperat...
# 92  [power of the solar cell module, and the measu...
#
#                                                  col3  \
# 0                [for operating a solar cell array\n]
# 1   [The invention relates to, relates to a method...
# 2                                                  []
# 3   [so-called regenerative energies, solar energy...
# 4   [To bring energy closer to, economic standard ...
# ..                                                ...
# 88                                                 []
# 89                                                 []
# 90  [view of a solar cell array, to ground lying) ...
# 91  [of a further solar cell arrangement, temperat...
# 92  [power of the solar cell module, and the measu...
#
#                                                  col4  \
# 0                [for operating a solar cell array\n]
# 1   [The invention relates to, relates to a method...
# 2                                                  []
# 3   [so-called regenerative energies, solar energy...
# 4   [To bring energy closer to, economic standard ...
# ..                                                ...
# 88                                                 []
# 89                                                 []
# 90  [view of a solar cell array, to ground lying) ...
# 91  [of a further solar cell arrangement, temperat...
# 92  [power of the solar cell module, and the measu...
#
#                                                  col5  \
# 0                [for operating a solar cell array\n]
# 1   [The invention relates to, relates to a method...
# 2                                                  []
# 3   [so-called regenerative energies, solar energy...
# 4   [To bring energy closer to, economic standard ...
# ..                                                ...
# 88                                                 []
# 89                                                 []
# 90  [view of a solar cell array, to ground lying) ...
# 91  [of a further solar cell arrangement, temperat...
# 92  [power of the solar cell module, and the measu...
#
#                                                  col6  \
# 0                [for operating a solar cell array\n]
# 1   [The invention relates to, relates to a method...
# 2                                                  []
# 3   [so-called regenerative energies, solar energy...
# 4   [To bring energy closer to, economic standard ...
# ..                                                ...
# 88                                                 []
# 89                                                 []
# 90  [view of a solar cell array, to ground lying) ...
# 91  [of a further solar cell arrangement, temperat...
# 92  [power of the solar cell module, and the measu...
#
#                                                  col7  \
# 0                [for operating a solar cell array\n]
# 1   [The invention relates to, relates to a method...
# 2                                                  []
# 3   [so-called regenerative energies, solar energy...
# 4   [To bring energy closer to, economic standard ...
# ..                                                ...
# 88                                                 []
# 89                                                 []
# 90  [view of a solar cell array, to ground lying) ...
# 91  [of a further solar cell arrangement, temperat...
# 92  [power of the solar cell module, and the measu...
#
#                                                  col8  \
# 0                [for operating a solar cell array\n]
# 1   [The invention relates to, relates to a method...
# 2                                                  []
# 3   [so-called regenerative energies, solar energy...
# 4   [To bring energy closer to, economic standard ...
# ..                                                ...
# 88                                                 []
# 89                                                 []
# 90  [view of a solar cell array, to ground lying) ...
# 91  [of a further solar cell arrangement, temperat...
# 92  [power of the solar cell module, and the measu...
#
#                                                  col9
# 0                [for operating a solar cell array\n]
# 1   [The invention relates to, relates to a method...
# 2                                                  []
# 3   [so-called regenerative energies, solar energy...
# 4   [To bring energy closer to, economic standard ...
# ..                                                ...
# 88                                                 []
# 89                                                 []
# 90  [view of a solar cell array, to ground lying) ...
# 91  [of a further solar cell arrangement, temperat...
# 92  [power of the solar cell module, and the measu...
#
# [93 rows x 11 columns]

# %%
tic=time.time()

somanytimes = 100
for i in range(somanytimes):
    name_col='col' + str(i)
    desc_df[name_col]=desc_df['lines'].apply(look4wordsintext)
toc=time.time()
print(f'{len(desc_df) * somanytimes} times in {toc-tic} seconds')
# Out:
# 9300 times in 0.4839918613433838 seconds

# %%
desc_df
# Out:
#                                                 lines  \
# 0    Method and arrangement for operating a solar ...
# 1   The invention relates to a method for operatin...
# 2                                  State of the art\n
# 3   Among the so-called regenerative energies, sol...
# 4   To bring energy closer to the values that set ...
# ..                                                ...
# 88                                     ? = P ou Xt)\n
# 89                           Figure imgf000009_0001\n
# 90  P m (t) PJ in cvcle Fig. 2A shows a sketch-lik...
# 91  FIG. 3 shows a sketch of a further solar cell ...
# 92  Finally, FIG. 4 schematically shows a modifica...
#
#                                                  col0  \
# 0                [for operating a solar cell array\n]
# 1   [The invention relates to, relates to a method...
# 2                                                  []
# 3   [so-called regenerative energies, solar energy...
# 4   [To bring energy closer to, economic standard ...
# ..                                                ...
# 88                                                 []
# 89                                                 []
# 90  [view of a solar cell array, to ground lying) ...
# 91  [of a further solar cell arrangement, temperat...
# 92  [power of the solar cell module, and the measu...
#
#                                                  col1  \
# 0                [for operating a solar cell array\n]
# 1   [The invention relates to, relates to a method...
# 2                                                  []
# 3   [so-called regenerative energies, solar energy...
# 4   [To bring energy closer to, economic standard ...
# ..                                                ...
# 88                                                 []
# 89                                                 []
# 90  [view of a solar cell array, to ground lying) ...
# 91  [of a further solar cell arrangement, temperat...
# 92  [power of the solar cell module, and the measu...
#
#                                                  col2  \
# 0                [for operating a solar cell array\n]
# 1   [The invention relates to, relates to a method...
# 2                                                  []
# 3   [so-called regenerative energies, solar energy...
# 4   [To bring energy closer to, economic standard ...
# ..                                                ...
# 88                                                 []
# 89                                                 []
# 90  [view of a solar cell array, to ground lying) ...
# 91  [of a further solar cell arrangement, temperat...
# 92  [power of the solar cell module, and the measu...
#
#                                                  col3  \
# 0                [for operating a solar cell array\n]
# 1   [The invention relates to, relates to a method...
# 2                                                  []
# 3   [so-called regenerative energies, solar energy...
# 4   [To bring energy closer to, economic standard ...
# ..                                                ...
# 88                                                 []
# 89                                                 []
# 90  [view of a solar cell array, to ground lying) ...
# 91  [of a further solar cell arrangement, temperat...
# 92  [power of the solar cell module, and the measu...
#
#                                                  col4  \
# 0                [for operating a solar cell array\n]
# 1   [The invention relates to, relates to a method...
# 2                                                  []
# 3   [so-called regenerative energies, solar energy...
# 4   [To bring energy closer to, economic standard ...
# ..                                                ...
# 88                                                 []
# 89                                                 []
# 90  [view of a solar cell array, to ground lying) ...
# 91  [of a further solar cell arrangement, temperat...
# 92  [power of the solar cell module, and the measu...
#
#                                                  col5  \
# 0                [for operating a solar cell array\n]
# 1   [The invention relates to, relates to a method...
# 2                                                  []
# 3   [so-called regenerative energies, solar energy...
# 4   [To bring energy closer to, economic standard ...
# ..                                                ...
# 88                                                 []
# 89                                                 []
# 90  [view of a solar cell array, to ground lying) ...
# 91  [of a further solar cell arrangement, temperat...
# 92  [power of the solar cell module, and the measu...
#
#                                                  col6  \
# 0                [for operating a solar cell array\n]
# 1   [The invention relates to, relates to a method...
# 2                                                  []
# 3   [so-called regenerative energies, solar energy...
# 4   [To bring energy closer to, economic standard ...
# ..                                                ...
# 88                                                 []
# 89                                                 []
# 90  [view of a solar cell array, to ground lying) ...
# 91  [of a further solar cell arrangement, temperat...
# 92  [power of the solar cell module, and the measu...
#
#                                                  col7  \
# 0                [for operating a solar cell array\n]
# 1   [The invention relates to, relates to a method...
# 2                                                  []
# 3   [so-called regenerative energies, solar energy...
# 4   [To bring energy closer to, economic standard ...
# ..                                                ...
# 88                                                 []
# 89                                                 []
# 90  [view of a solar cell array, to ground lying) ...
# 91  [of a further solar cell arrangement, temperat...
# 92  [power of the solar cell module, and the measu...
#
#                                                  col8  \
# 0                [for operating a solar cell array\n]
# 1   [The invention relates to, relates to a method...
# 2                                                  []
# 3   [so-called regenerative energies, solar energy...
# 4   [To bring energy closer to, economic standard ...
# ..                                                ...
# 88                                                 []
# 89                                                 []
# 90  [view of a solar cell array, to ground lying) ...
# 91  [of a further solar cell arrangement, temperat...
# 92  [power of the solar cell module, and the measu...
#
#                                                  col9
# 0                [for operating a solar cell array\n]
# 1   [The invention relates to, relates to a method...
# 2                                                  []
# 3   [so-called regenerative energies, solar energy...
# 4   [To bring energy closer to, economic standard ...
# ..                                                ...
# 88                                                 []
# 89                                                 []
# 90  [view of a solar cell array, to ground lying) ...
# 91  [of a further solar cell arrangement, temperat...
# 92  [power of the solar cell module, and the measu...
#
# [93 rows x 11 columns]

# %%
dff = pd.DataFrame(data={'numeros':range(1,100000)})

# %%
tic=time.time()
summed=0
for _,row in dff.iterrows():
    summed += row['numeros']
    
print(summed)
toc = time.time() 
print(f'elapsed time {toc-tic} seconds' )
# Out:
# 4999950000
# elapsed time 15.205833911895752 seconds

# %%
tic=time.time()
summed=0
for row in dff.itertuples():
    summed += row.numeros
    
print(summed)
toc = time.time() 
print(f'elapsed time {toc-tic} seconds' )
# Out:
# 4999950000
# elapsed time 0.1870105266571045 seconds
