# %%
import pandas as pd

# %%
yann_df = pd.read_csv('lipa_sipto.csv')

# %%
yann_df
# Out:
#      Unnamed: 0                       AP                        PN  \
# 0             0  CN201910205498 20120629    CN109905904 A 20190618
# 1             1   EP20190174532 20120120     EP3544326 A1 20190925
# 2             2  US201816227196 20181220  US2019124717 A1 20190425
# 3             3  US201615764513 20160930  US2019059030 A1 20190221
# 4             4  US201816116260 20180829  US2018376529 A1 20181227
# ..          ...                      ...                       ...
# 200           0   WO2011US20838 20110111  WO2011085370 A2 20110714
# 201           1   WO2011US20637 20110110  WO2011085290 A1 20110714
# 202           2   WO2010US58940 20101203  WO2011069092 A1 20110609
# 203           3   EP20100751896 20100824     EP2609779 A1 20130703
# 204           4   WO2010EP62347 20100824  WO2012025149 A1 20120301
#
#              PD                                                 PR  \
# 0    2019-06-18   CN201910205498 20120629; CN201210226993 20120629
# ...

# %%
yann_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 9 columns):
# Unnamed: 0    205 non-null int64
# AP            205 non-null object
# PN            205 non-null object
# PD            205 non-null object
# PR            205 non-null object
# CCI           195 non-null object
# CCA           174 non-null object
# TI            205 non-null object
# PD_dt64       205 non-null object
# dtypes: int64(1), object(8)
# memory usage: 14.5+ KB

# %% [markdown]
# We see that the data does not have format.
# Perhaps in the real response in beagle it will
# Now assuming it doesnt we might be interested in giving it format

# %%
yann_df['CCI'].astype(str)
# Out:
# 0                                             H04W36/125
# 1                                              H04W76/11
# 2                                              H04W76/32
# 3      H04L5/001; H04L5/0098; H04W36/0069; H04W36/08;...
# 4                                   H04W76/12; H04W76/15
#                              ...
# 200                                            H04W48/08
# 201                                            H04W48/17
# 202                     H04L63/30; H04W8/082; H04W12/001
# 203                                            H04W68/00
# 204                                            H04W68/00
# Name: CCI, Length: 205, dtype: object

# %%
yann_df.info()
# did not change because it was not inplace
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 9 columns):
# Unnamed: 0    205 non-null int64
# AP            205 non-null object
# PN            205 non-null object
# PD            205 non-null object
# PR            205 non-null object
# CCI           205 non-null object
# CCA           174 non-null object
# TI            205 non-null object
# PD_dt64       205 non-null object
# dtypes: int64(1), object(8)
# memory usage: 14.5+ KB

# %%
yann_df['CCI']= yann_df['CCI'].to_string

# %%
yann_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 9 columns):
# Unnamed: 0    205 non-null int64
# AP            205 non-null object
# PN            205 non-null object
# PD            205 non-null object
# PR            205 non-null object
# CCI           205 non-null object
# CCA           174 non-null object
# TI            205 non-null object
# PD_dt64       205 non-null object
# dtypes: int64(1), object(8)
# memory usage: 14.5+ KB

# %%
yann_df['CCI']= yann_df['CCI'].to_string()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-42d624e68a2f> in <module>
# ----> 1 yann_df['CCI']= yann_df['CCI'].to_string()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\series.py in to_string(self, buf, na_rep, float_format, header, index, length, dtype, name, max_rows, min_rows)
#    1679             max_rows=max_rows,
#    1680         )
# -> 1681         result = formatter.to_string()
#    1682
#    1683         # catch contract violations
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\formats\format.py in to_string(self)
#     311
#     312         fmt_index, have_header = self._get_formatted_index()
# --> 313         fmt_values = self._get_formatted_values()
#     314
#     315         if self.truncate_v:
#
# ...

# %%
yann_df.info()
